# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp = pd.read_csv('Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
temp.iloc[0:3]
# Out:
# 10.74074074074074

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
temp.iloc[0:3]['Temperature'].mean()
# Out:
# 10.74074074074074

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
temp[temp.Temperature > 15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
temp[temp.Temperature > 15]["City"]
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
temp[temp.Temperature > 15][temp.Temperature < 20]["City"]
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
#temp['Temperature'].mean()
#temp['Temperature'].std()

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee = pd.read_csv('employee.csv')
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here
employee.hist()

#Distribution of Years worked at the company and the Distribution of Salary
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1222d1358>,
# ...
#       dtype=object)

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
employee.mean()["Salary"]
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
employee.max()["Salary"]
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
employee.min()["Salary"]
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here

employee[employee.Salary == 30]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee[employee.Name == 'David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
employee[employee.Name == 'David']["Salary"]
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
employee[employee.Title == 'associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.iloc[0:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee.iloc[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee[(employee.Title == 'associate') & (employee.Salary > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
year = employee['Salary'].groupby(employee['Years']) 
print(year.mean())
# Out:
# Years
# 1    35.000000
# 2    38.333333
# 3    55.000000
# 4    35.000000
# 7    60.000000
# 8    70.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
salary = employee['Salary'].groupby(employee['Title']) 
print(salary.mean())
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
# %matplotlib inline

employee.boxplot()

# %%
# print first quartile here

# %%
# print third quartile here

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
wage_gap = employee['Salary'].groupby(employee['Gender']) 
print(wage_gap.mean()) 
# Yes female are paid less
# Out:
# Gender
# F    47.5
# M    50.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
years1 = employee['Years'].groupby(employee['Department']) 
print('Years Mean', years1.mean())  
print('Years Min', years1.min())
print('Years Max', years1.max())



salary1 = employee['Salary'].groupby(employee['Department']) 
print('Salary Mean', salary1.mean())  
print('Salary Min', salary1.min())
print('Salary Max', salary1.max())
# Out:
# Years Mean Department
# HR       4.666667
# IT       4.500000
# Sales    2.500000
# Name: Years, dtype: float64
# Years Min Department
# HR       2
# IT       1
# Sales    2
# Name: Years, dtype: int64
# Years Max Department
# HR       8
# IT       8
# Sales    3
# Name: Years, dtype: int64
# Salary Mean Department
# HR       45.00
# IT       48.75
# Sales    55.00
# Name: Salary, dtype: float64
# Salary Min Department
# HR       30
# IT       30
# Sales    55
# Name: Salary, dtype: int64
# Salary Max Department
# HR       70
# IT       70
# Sales    55
# Name: Salary, dtype: int64

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders = pd.read_csv('Orders.csv')

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
# your answer here
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
orders['UnitPrice'].mean()
# Out:
# 3.116174480549152

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
orders['UnitPrice'].min()
# Out:
# 0.0

# %%
# your answer here
orders['UnitPrice'].max()
# Out:
# 8142.75

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
orders['CustomerID']
# Out:
# 0         17850
# 1         17850
# 2         17850
# 3         17850
# 4         17850
# 5         17850
# 6         17850
# 7         17850
# 8         17850
# 9         13047
# 10        13047
# 11        13047
# 12        13047
# 13        13047
# 14        13047
# 15        13047
# 16        13047
# 17        13047
# 18        13047
# 19        13047
# 20        13047
# 21        13047
# 22        13047
# 23        13047
# 24        13047
# 25        13047
# 26        12583
# 27        12583
# 28        12583
# 29        12583
#           ...
# 397894    15804
# 397895    15804
# 397896    15804
# 397897    15804
# 397898    15804
# 397899    15804
# 397900    15804
# 397901    15804
# 397902    15804
# 397903    15804
# 397904    15804
# 397905    13113
# 397906    13113
# 397907    13113
# 397908    13113
# 397909    12680
# 397910    12680
# 397911    12680
# 397912    12680
# 397913    12680
# 397914    12680
# 397915    12680
# 397916    12680
# 397917    12680
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
orders.CustomerID.value_counts()
# Out:
# 17841    7847
# 14911    5677
# 14096    5111
# 12748    4596
# 14606    2700
# 15311    2379
# 14646    2080
# 13089    1818
# 13263    1677
# 14298    1637
# 15039    1502
# 14156    1400
# 18118    1279
# 14159    1204
# 14796    1141
# 16033    1137
# 15005    1119
# 14056    1106
# 14769    1090
# 13081    1028
# 16549     981
# 14527     972
# 14456     970
# 17511     963
# 15719     937
# 15555     899
# 16931     898
# 17811     851
# 14505     799
# 18283     756
#          ...
# 16073       1
# 14351       1
# 16881       1
# 14424       1
# 18084       1
# 18133       1
# 17752       1
# 13017       1
# 17102       1
# 18174       1
# 17443       1
# 17763       1
# 13270       1
# 15070       1
# 15389       1
# 13099       1
# 15510       1
# 13391       1
# 13135       1
# 16742       1
# 17956       1
# 15562       1
# 17923       1
# 17715       1
# 15195       1
# 17331       1
# 16093       1
# 13703       1
# 13307       1
# 12346       1
# ...

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
orders[(orders.Quantity > 50)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 46              46     536371     22086  2010     12    3     9
# 83              83     536376     21733  2010     12    3     9
# 96              96     536378     21212  2010     12    3     9
# 102            102     536378    85071B  2010     12    3     9
# 174            176     536386    85099C  2010     12    3     9
# 175            177     536386    85099B  2010     12    3     9
# 176            178     536387     79321  2010     12    3     9
# 177            179     536387     22780  2010     12    3     9
# 178            180     536387     22779  2010     12    3     9
# 179            181     536387     22466  2010     12    3     9
# 180            182     536387     21731  2010     12    3     9
# 215            217     536390    84970S  2010     12    3    10
# 217            219     536390     20668  2010     12    3    10
# 218            220     536390    85123A  2010     12    3    10
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
#salary = employee['Salary'].groupby(employee['Title']) 
#print(salary.mean())  

orders[(orders.Country == 'Spain') & (orders.Quantity > 50)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
orders[(orders.amount_spent == 0)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
orders[(orders.Description == 'lunch bag')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, InvoiceNo, StockCode, year, month, day, hour, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, amount_spent]
# Index: []

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here

spain = orders[(orders.Country == 'Spain')].groupby(orders['amount_spent']) 
print(spain.mean())
# Out:
#                  Unnamed: 0      InvoiceNo         year      month       day  \
# amount_spent
# 0.00          282912.000000  561669.000000  2011.000000   7.000000  4.000000
# 0.21          535260.000000  581193.000000  2011.000000  12.000000  3.000000
# 0.29          258626.000000  559665.000000  2011.000000   7.000000  1.000000
# 0.39          443043.666667  574017.000000  2011.000000  10.333333  2.333333
# 0.42           21570.000000  538095.000000  2010.000000  12.000000  4.000000
# 0.55          258671.000000  559665.000000  2011.000000   7.000000  1.000000
# 0.78          535254.500000  581193.000000  2011.000000  12.000000  3.000000
# 0.79          443045.666667  574017.000000  2011.000000  10.333333  2.333333
# 0.83          440884.000000  574550.000000  2011.000000  11.000000  5.000000
# 0.84          419080.500000  572335.000000  2011.000000  10.000000  2.500000
# 0.85          321865.000000  563962.200000  2010.800000  10.000000  2.400000
# ...

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here

orders[(orders.month == 8)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# 199480      285426     561905     84978  2011      8    1     9
# 199481      285427     561905     21754  2011      8    1     9
# 199482      285428     561905     23226  2011      8    1     9
# 199483      285429     561905     21715  2011      8    1     9
# 199484      285430     561905     21716  2011      8    1     9
# 199485      285431     561905     21746  2011      8    1     9
# 199486      285432     561905     21755  2011      8    1     9
# 199487      285433     561906     22367  2011      8    1    10
# 199488      285434     561906     20914  2011      8    1    10
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
august = orders[(orders.month == 8)].groupby(orders['Country'])
print(august.InvoiceNo.value_counts())

#orders.CustomerID.value_counts()
# Out:
# Country          InvoiceNo
# Australia        563614        97
#                  563179        10
# Austria          562602        58
#                  563749        30
# Belgium          562034        39
#                  564378        35
#                  563854        34
#                  563037        30
#                  562445        21
#                  563172        12
#                  564853        12
#                  563852         7
#                  564481         4
# Canada           564428         5
# Channel Islands  564150        57
#                  564093        55
#                  562017        13
#                  564095        11
#                  563900         4
# Denmark          562853        16
# EIRE             562560       147
#                  562670        58
#                  563848        49
#                  563558        48
#                  563098        41
#                  564565        41
# ...

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
